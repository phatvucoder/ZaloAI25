# %%
# !git clone https://github.com/phatvucoder/ZaloAI25.git
# !pip install -q gdown opencv-python
# %cd ZaloAI25
# Out:
# Cloning into 'ZaloAI25'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (33/33), done.
# Receiving objects: 100% (53/53), 27.61 KiB | 3.94 MiB/s, done.
# remote: Total 53 (delta 18), reused 45 (delta 14), pack-reused 0 (from 0)
# Resolving deltas: 100% (18/18), done.
# /content/ZaloAI25

# %%
# !date
# !unzip -q /content/drive/MyDrive/Dev-Drive/competitions/2025/ZaloAI/data/yolo_dataset_all.zip -d .
# !date
# Out:
# Mon Nov 17 03:27:44 PM UTC 2025
# Mon Nov 17 03:36:04 PM UTC 2025

# %%
# !rm -rf /content/ZaloAI25/dataset/subset

# %%
# !python -m utils.data.build_subyolo --config configs/data.yaml --annotated 5 25 --non_annotated 5 25
# Out:
# Analyzing existing YOLO dataset...
# Analyzing dataset: 100% 80729/80729 [00:11<00:00, 6937.45it/s]
# Found 20106 annotated frames and 60623 non-annotated frames
# Creating subset...
# Processing videos: 100% 14/14 [01:45<00:00,  7.51s/it]
#
# Subset creation complete!
# Selected 16207 frames
# Output directory: /content/ZaloAI25/dataset/subset/yolo_dataset
# Sampling parameters:
#   Annotated: keep 5 frames every 25 frames
#   Non-annotated: keep 5 frames every 25 frames

# %%
# !du -sh /content/ZaloAI25/dataset/subset/yolo_dataset
# !du -sh /content/ZaloAI25/dataset/subset/yolo_dataset/*
# Out:
# 4.2G	/content/ZaloAI25/dataset/subset/yolo_dataset
# 4.2G	/content/ZaloAI25/dataset/subset/yolo_dataset/images
# 17M	/content/ZaloAI25/dataset/subset/yolo_dataset/labels
# 4.0K	/content/ZaloAI25/dataset/subset/yolo_dataset/splits

# %%
# !zip -r -q /content/drive/MyDrive/Dev-Drive/competitions/2025/ZaloAI/data/yolo_dataset_5_5.zip /content/ZaloAI25/dataset/subset/yolo_dataset
