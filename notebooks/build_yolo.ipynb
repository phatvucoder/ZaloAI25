# %%
# !git clone https://github.com/phatvucoder/ZaloAI25.git
# !pip install -q gdown opencv-python
# %cd ZaloAI25
# Out:
# Cloning into 'ZaloAI25'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 25 (delta 6), reused 21 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 16.05 KiB | 16.05 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/ZaloAI25

# %%
RAW_DATA_PATH="dataset/raw"

# %%
# !mkdir -p $RAW_DATA_PATH
# !gdown 1JZUsbAsjpbDpMIaWRcNyfyCVQxS89vhp
# !unzip observing.zip -d $RAW_DATA_PATH
# !rm observing.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JZUsbAsjpbDpMIaWRcNyfyCVQxS89vhp
# From (redirected): https://drive.google.com/uc?id=1JZUsbAsjpbDpMIaWRcNyfyCVQxS89vhp&confirm=t&uuid=6989a7b1-fca5-493b-854f-0dd7d6d156db
# To: /content/ZaloAI25/observing.zip
# 100% 636M/636M [00:10<00:00, 62.0MB/s]
# Archive:  observing.zip
#    creating: dataset/raw/train/
#    creating: dataset/raw/train/samples/
#    creating: dataset/raw/train/samples/Backpack_0/
#    creating: dataset/raw/train/samples/Backpack_0/object_images/
#   inflating: dataset/raw/train/samples/Backpack_0/object_images/img_1.jpg
#   inflating: dataset/raw/train/samples/Backpack_0/object_images/img_2.jpg
#   inflating: dataset/raw/train/samples/Backpack_0/object_images/img_3.jpg
#   inflating: dataset/raw/train/samples/Backpack_0/drone_video.mp4
#    creating: dataset/raw/train/samples/Backpack_1/
#    creating: dataset/raw/train/samples/Backpack_1/object_images/
# ...

# %%
# !date
# !python -m utils.data.build_yolo --config configs/data.yaml --mode turbo
# !date
# Out:
# Mon Nov 17 10:15:41 AM UTC 2025
# Loading annotations...
# Processing videos...
# Running in TURBO mode - maximum performance
# Using 2 parallel workers
# Batch size: 32
# NumPy optimizations: True
# Processing videos: 100% 14/14 [10:33<00:00, 45.22s/it]
# Copying object images...
#
# Dataset generation complete!
# Output directory: /content/ZaloAI25/dataset/yolo_dataset
# Mode used: turbo
# Mon Nov 17 10:26:15 AM UTC 2025

# %%
# !du -sh /content/ZaloAI25/dataset/yolo_dataset
# !du -sh /content/ZaloAI25/dataset/yolo_dataset/*
# Out:
# 21G	/content/ZaloAI25/dataset/yolo_dataset
# 21G	/content/ZaloAI25/dataset/yolo_dataset/images
# 83M	/content/ZaloAI25/dataset/yolo_dataset/labels
# 41M	/content/ZaloAI25/dataset/yolo_dataset/objects
# 4.0K	/content/ZaloAI25/dataset/yolo_dataset/splits

# %%
# !zip -r -q /content/drive/MyDrive/Dev-Drive/competitions/2025/ZaloAI/data/objects.zip dataset/yolo_dataset/objects

# %%
# !zip -r -q /content/drive/MyDrive/Dev-Drive/competitions/2025/ZaloAI/data/yolo_dataset_all.zip dataset/yolo_dataset
